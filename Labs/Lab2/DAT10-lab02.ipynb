# %% [markdown]
# # GA Data Science 10 (DAT5) - Lab2
#
# ### Importing Data - JSON, CSVs, APIs
#
# Craig Sakuma

# %% [markdown]
# ### Last time we covered introductions to:
# - #### Python
# - #### iPython Notebooks
# - #### numpy
# - #### Pandas
#
# #### Questions?

# %% [markdown]
# ### Agenda
#
# 1. JSON
# 2. API

# %% [markdown]
# # 1. JSON

# %% [markdown]
# - What's Json? (and why do we care?)

# %%
# load the homework data into a pandas dataset

import pandas as pd

data = pd.read_csv("titanic-train.csv")

# %%
# assign the first 5 rows to a variable called first

first = data.head(5)

# %%
first
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# use the DataFrame method to_json to transform <first> into a json object
first.to_json()
# Out:
# '{"PassengerId":{"0":1,"1":2,"2":3,"3":4,"4":5},"Survived":{"0":0,"1":1,"2":1,"3":1,"4":0},"Pclass":{"0":3,"1":1,"2":3,"3":1,"4":3},"Name":{"0":"Braund, Mr. Owen Harris","1":"Cumings, Mrs. John Bradley (Florence Briggs Thayer)","2":"Heikkinen, Miss. Laina","3":"Futrelle, Mrs. Jacques Heath (Lily May Peel)","4":"Allen, Mr. William Henry"},"Sex":{"0":"male","1":"female","2":"female","3":"female","4":"male"},"Age":{"0":22.0,"1":38.0,"2":26.0,"3":35.0,"4":35.0},"SibSp":{"0":1,"1":1,"2":0,"3":1,"4":0},"Parch":{"0":0,"1":0,"2":0,"3":0,"4":0},"Ticket":{"0":"A\\/5 21171","1":"PC 17599","2":"STON\\/O2. 3101282","3":"113803","4":"373450"},"Fare":{"0":7.25,"1":71.2833,"2":7.925,"3":53.1,"4":8.05},"Cabin":{"0":null,"1":"C85","2":null,"3":"C123","4":null},"Embarked":{"0":"S","1":"C","2":"S","3":"S","4":"S"}}'

# %%
# explore the different options in the to_json method
first.to_json(orient = 'records')
# Out:
# '[{"PassengerId":1,"Survived":0,"Pclass":3,"Name":"Braund, Mr. Owen Harris","Sex":"male","Age":22.0,"SibSp":1,"Parch":0,"Ticket":"A\\/5 21171","Fare":7.25,"Cabin":null,"Embarked":"S"},{"PassengerId":2,"Survived":1,"Pclass":1,"Name":"Cumings, Mrs. John Bradley (Florence Briggs Thayer)","Sex":"female","Age":38.0,"SibSp":1,"Parch":0,"Ticket":"PC 17599","Fare":71.2833,"Cabin":"C85","Embarked":"C"},{"PassengerId":3,"Survived":1,"Pclass":3,"Name":"Heikkinen, Miss. Laina","Sex":"female","Age":26.0,"SibSp":0,"Parch":0,"Ticket":"STON\\/O2. 3101282","Fare":7.925,"Cabin":null,"Embarked":"S"},{"PassengerId":4,"Survived":1,"Pclass":1,"Name":"Futrelle, Mrs. Jacques Heath (Lily May Peel)","Sex":"female","Age":35.0,"SibSp":1,"Parch":0,"Ticket":"113803","Fare":53.1,"Cabin":"C123","Embarked":"S"},{"PassengerId":5,"Survived":0,"Pclass":3,"Name":"Allen, Mr. William Henry","Sex":"male","Age":35.0,"SibSp":0,"Parch":0,"Ticket":"373450","Fare":8.05,"Cabin":null,"Embarked":"S"}]'

# %% [markdown]
# # 2. APIs

# %% [markdown]
# - What's an API? (and why do we care?)

# %% [markdown]
# ## 2.a A simple web request

# %%
import urllib

def get_historical_prices(symbol, start_date, end_date):
    """
    Get historical prices for the given ticker symbol.
    Date format is 'YYYYMMDD'
    
    Returns a json list.
    """
    url = 'http://ichart.yahoo.com/table.csv?s=%s&' % symbol + \
          'd=%s&' % str(int(end_date[4:6]) - 1) + \
          'e=%s&' % str(int(end_date[6:8])) + \
          'f=%s&' % str(int(end_date[0:4])) + \
          'g=d&' + \
          'a=%s&' % str(int(start_date[4:6]) - 1) + \
          'b=%s&' % str(int(start_date[6:8])) + \
          'c=%s&' % str(int(start_date[0:4])) + \
          'ignore=.csv'
    days = urllib.urlopen(url).readlines()
#     return days
    data = [day[:-2].split(',') for day in days]
    return data

# %%
get_historical_prices('GOOGL', '20140101', '20140106')
# Out:
# [['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Clos'],
#  ['2014-01-06',
#   '1113.01',
#   '1118.86',
#   '1106.44',
#   '1117.32',
#   '3535000',
#   '559.2'],
#  ['2014-01-03',
#   '1115.00',
#   '1116.93',
#   '1104.93',
#   '1105.00',
#   '3330000',
#   '553.0'],
#  ['2014-01-02',
#   '1115.46',
#   '1117.75',
#   '1108.26',
#   '1113.12',
#   '3639100',
#   '557.1']]

# %%
# obtain the prices of Yahoo for the past month and insert them in a Pandas Dataframe

prices =get_historical_prices('YHOO', '20140217', '20140317')

df = pd.DataFrame(prices[1:], columns= prices[0], dtype=float).set_index('Date')
df.head()
# Out:
#              Open   High    Low  Close    Volume  Adj Clos
# Date
# 2014-03-17  39.00  39.36  38.61  39.11  29698300      39.1
# 2014-03-14  36.69  38.19  36.45  37.60  30862300      37.6
# 2014-03-13  38.05  38.42  36.81  37.23  21179700      37.2
# 2014-03-12  37.21  37.61  36.48  37.50  14794700      37.5
# 2014-03-11  38.25  38.30  37.43  37.56  12592300      37.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 2014-03-17 to 2014-02-18
# Data columns (total 6 columns):
# Open        20 non-null float64
# High        20 non-null float64
# Low         20 non-null float64
# Close       20 non-null float64
# Volume      20 non-null float64
# Adj Clos    20 non-null float64
# dtypes: float64(6)

# %% [markdown]
# ### Exercise 1
# ##### Create a pandas dataframe with all the stock price data for Alibaba (BABA)
# ##### What was the highest trading price of the Alibaba stock?
# ##### What was the lowest trading price of the Alibaba stock?
#
# #### Hint: Look in pandas documentation or stackoverflow
#
# ### Bonus Question
# ##### What were the Yahoo highs and lows for the same days as the Alibaba highs and lows?

# %%
df.index[df.High==df.High.max()]
# Out:
#              Open   High    Low  Close    Volume  Adj Clos
# Date
# 2014-03-05  39.83  40.15  39.19   39.5  12536800      39.5

# %% [markdown]
# ## 2.b Unstructured data

# %% [markdown]
# #### HTTP requests can be handled easily using Python's `requests` library.
#
# First we will load our credentials which we keep in a [YAML](http://www.yaml.org/) file for safe keeping.

# %%
import yaml
credentials = yaml.load(open('/users/Craig_Sakuma/api_cred.yml'))

# %% [markdown]
# Then we pass those credentials in to a GET request using the requests library. In this case, I am querying my own user data from Github:

# %%
import requests
r = requests.get('https://api.github.com/user', 
                 auth=(credentials['USER'], credentials['PASS']))

# %% [markdown]
# Requests gives us an object from which we can read its content.

# %%
r.content
# Out:
# '{"login":"craigsakuma","id":4754768,"avatar_url":"https://avatars.githubusercontent.com/u/4754768?v=2","gravatar_id":"","url":"https://api.github.com/users/craigsakuma","html_url":"https://github.com/craigsakuma","followers_url":"https://api.github.com/users/craigsakuma/followers","following_url":"https://api.github.com/users/craigsakuma/following{/other_user}","gists_url":"https://api.github.com/users/craigsakuma/gists{/gist_id}","starred_url":"https://api.github.com/users/craigsakuma/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/craigsakuma/subscriptions","organizations_url":"https://api.github.com/users/craigsakuma/orgs","repos_url":"https://api.github.com/users/craigsakuma/repos","events_url":"https://api.github.com/users/craigsakuma/events{/privacy}","received_events_url":"https://api.github.com/users/craigsakuma/received_events","type":"User","site_admin":false,"public_repos":3,"public_gists":0,"followers":1,"following":3,"created_at":"2013-06-21T01:32:11Z","updated_at":"2014-10-07T02:00:21Z","private_gists":0,"total_private_repos":0,"owned_private_repos":0,"disk_usage":88748,"collaborators":0,"plan":{"name":"free","space":307200,"collaborators":0,"private_repos":0}}'

# %% [markdown]
# #### One of the reasons we like JSON is that it is easy to transform into a Python `dict` object using the `json` library:

# %%
import json
user = json.loads(r.content)
user
# Out:
# {u'avatar_url': u'https://avatars.githubusercontent.com/u/4754768?v=2',
#  u'collaborators': 0,
#  u'created_at': u'2013-06-21T01:32:11Z',
#  u'disk_usage': 88748,
#  u'events_url': u'https://api.github.com/users/craigsakuma/events{/privacy}',
#  u'followers': 1,
#  u'followers_url': u'https://api.github.com/users/craigsakuma/followers',
#  u'following': 3,
#  u'following_url': u'https://api.github.com/users/craigsakuma/following{/other_user}',
#  u'gists_url': u'https://api.github.com/users/craigsakuma/gists{/gist_id}',
#  u'gravatar_id': u'',
#  u'html_url': u'https://github.com/craigsakuma',
#  u'id': 4754768,
#  u'login': u'craigsakuma',
#  u'organizations_url': u'https://api.github.com/users/craigsakuma/orgs',
#  u'owned_private_repos': 0,
#  u'plan': {u'collaborators': 0,
#   u'name': u'free',
#   u'private_repos': 0,
#   u'space': 307200},
#  u'private_gists': 0,
#  u'public_gists': 0,
#  u'public_repos': 3,
#  u'received_events_url': u'https://api.github.com/users/craigsakuma/received_events',
#  u'repos_url': u'https://api.github.com/users/craigsakuma/repos',
#  u'site_admin': False,
#  u'starred_url': u'https://api.github.com/users/craigsakuma/starred{/owner}{/repo}',
#  u'subscriptions_url': u'https://api.github.com/users/craigsakuma/subscriptions',
#  u'total_private_repos': 0,
#  u'type': u'User',
#  u'updated_at': u'2014-10-07T02:00:21Z',
#  u'url': u'https://api.github.com/users/craigsakuma'}

# %%
print user.keys()
# Out:
# [u'disk_usage', u'private_gists', u'site_admin', u'subscriptions_url', u'gravatar_id', u'id', u'followers_url', u'following_url', u'collaborators', u'total_private_repos', u'followers', u'type', u'public_repos', u'gists_url', u'owned_private_repos', u'events_url', u'html_url', u'updated_at', u'plan', u'received_events_url', u'starred_url', u'public_gists', u'organizations_url', u'url', u'created_at', u'avatar_url', u'repos_url', u'following', u'login']

# %% [markdown]
# We can access values in this dict directly (such as my hireable status) and even render the url of my avatar:

# %%
from IPython.display import HTML
print "Hireable: {}".format(user.get('hireable'))
HTML('<img src={} />'.format(user.get('avatar_url')))
# Out:
# Hireable: None
# <img src=https://avatars.githubusercontent.com/u/4754768?v=2 />

# %% [markdown]
# # Twitter API

# %% [markdown]
# Twitter has no less than 10 python libraries. We'll be using Python Twitter Tools because it's what's used in Mining the Social Web.

# %% [markdown]
# #### Some services (like Twitter) have released Python libraries of their own to make using their API even easier.

# %%
import twitter

auth = twitter.oauth.OAuth(credentials['OAUTH_TOKEN'], 
                           credentials['OAUTH_TOKEN_SECRET'],
                           credentials['CONSUMER_KEY'],
                           credentials['CONSUMER_SECRET'])

twitter_api = twitter.Twitter(auth=auth)

print twitter_api
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2efd6c59d756> in <module>()
#       1 import twitter
#       2
# ----> 3 auth = twitter.oauth.OAuth(credentials['OAUTH_TOKEN'],
#       4                            credentials['OAUTH_TOKEN_SECRET'],
#       5                            credentials['CONSUMER_KEY'],
#
# NameError: name 'credentials' is not defined

# %% [markdown]
# #### Using a library like this, we don't even need to specify the URL (that's handled internally).

# %% [markdown]
# Using a library like this, it's easy to do something like search for tweets mentioning `#bigdata`
#
# The results are transformed into a Python object (which in this case is a thin wrapper around a `dict`)

# %%
bigdata = twitter_api.search.tweets(q='#bigdata', count=5)
type(bigdata)
# Out:
# twitter.api.TwitterDictResponse

# %%
for status in bigdata['statuses']:
    print status.get('text')
# Out:
# #StopDataRetention
#
# #qt #auspol #brandis #snowden #asio #heyasio #privacy #surveillance #metadata #bigdata http://t.co/DJc1ppDyO3
# RT @TungstenBigData: Business Intelligence/Data Warehouse Architect (Full Time) http://t.co/Ni1UVA6yxy #BI #BigData
# RT @TungstenBigData: Business Intelligence/Data Warehouse Architect (Full Time) http://t.co/Ni1UVA6yxy #BI #BigData
# RT @datanami: Off The Wire: @Zoomdata Receives $17M in Funding http://t.co/0qrMAnoytJ #BigData
# RT @Shyam17: The next generation of data integration technology for the changing cloud market http://t.co/DWdhKHTAUo http://t.co/0XeuZ6x5xG…

# %% [markdown]
# # Twitter lab
# [http://tinyurl.com/GAtwitterlab](http://nbviewer.ipython.org/github/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/ipynb/Chapter%201%20-%20Mining%20Twitter.ipynb) up through Exercise 5

# %% [markdown]
# Useful links:
#
# [Mining the Social Web](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition)

# %%
# !pip install twitter
# Out:
# Requirement already satisfied (use --upgrade to upgrade): twitter in /Users/Craig_Sakuma/anaconda/lib/python2.7/site-packages
# Cleaning up...

# %%
import twitter

# %% [markdown]
# ### Create your own Twitter credentials:
#
# #### Step 1:
# Go to https://dev.twitter.com/apps and sign in.
#
# #### Step 2:
# Register an application (doesn't have to be real, just a placeholder)
#
# Website: http://example.com
#
# Callback URL: http://example.com/auth/twitter/callback/
#
# #### Step 3:
# Add api key and api secret to your yaml file
#
# #### Step 4:
# Click on generate token and add information into your yaml file

# %% [markdown]
# ### Create your own yaml file called api_cred.yml
# Use the credential_example.yml file as a template

# %%
import yaml

# %%
credentials = yaml.load(open('/Users/remi/dev/ga/twitter_credentials.yml'))
auth = twitter.oauth.OAuth(credentials['OAUTH_TOKEN'], 
                           credentials['OAUTH_TOKEN_SECRET'],
                           credentials['CONSUMER_KEY'],
                           credentials['CONSUMER_SECRET'])

# %%
twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print twitter_api
# Out:
# <twitter.api.Twitter object at 0x106682c90>

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print world_trends
print
print us_trends
# Out:
# [{u'created_at': u'2014-10-09T02:52:53Z', u'trends': [{u'url': u'http://twitter.com/search?q=%22Kathy+Bates%22', u'query': u'%22Kathy+Bates%22', u'name': u'Kathy Bates', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23QueLindoSeria', u'query': u'%23QueLindoSeria', u'name': u'#QueLindoSeria', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23LoQueMeRePuedeEs', u'query': u'%23LoQueMeRePuedeEs', u'name': u'#LoQueMeRePuedeEs', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23AHSFX', u'query': u'%23AHSFX', u'name': u'#AHSFX', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23TeJuroQue', u'query': u'%23TeJuroQue', u'name': u'#TeJuroQue', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Jimmy+Darlin%22', u'query': u'%22Jimmy+Darlin%22', u'name': u'Jimmy Darlin', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Tommy+Wingels%22', u'query': u'%22Tommy+Wingels%22', u'name': u'Tommy Wingels', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23BrazilCantWaitToSeeFifthHarmony', u'query': u'%23BrazilCantWaitToSeeFifthHarmony', u'name': u'#BrazilCantWaitToSeeFifthHarmony', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Ethel', u'query': u'Ethel', u'name': u'Ethel', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Bette+and+Dot%22', u'query': u'%22Bette+and+Dot%22', u'name': u'Bette and Dot', u'promoted_content': None}], u'as_of': u'2014-10-09T02:56:53Z', u'locations': [{u'woeid': 1, u'name': u'Worldwide'}]}]
#
# [{u'created_at': u'2014-10-09T02:49:34Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23AHSFX', u'query': u'%23AHSFX', u'name': u'#AHSFX', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Twisty', u'query': u'Twisty', u'name': u'Twisty', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23BetteAndDot', u'query': u'%23BetteAndDot', u'name': u'#BetteAndDot', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Key+%26+Peele%22', u'query': u'%22Key+%26+Peele%22', u'name': u'Key & Peele', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23HalsteadsRage', u'query': u'%23HalsteadsRage', u'name': u'#HalsteadsRage', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Soliman', u'query': u'Soliman', u'name': u'Soliman', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23ihateclowns', u'query': u'%23ihateclowns', u'name': u'#ihateclowns', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Evan+Peters%22', u'query': u'%22Evan+Peters%22', u'name': u'Evan Peters', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23HollywoodDivas', u'query': u'%23HollywoodDivas', u'name': u'#HollywoodDivas', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Jermain+Taylor%22', u'query': u'%22Jermain+Taylor%22', u'name': u'Jermain Taylor', u'promoted_content': None}], u'as_of': u'2014-10-09T02:56:53Z', u'locations': [{u'woeid': 23424977, u'name': u'United States'}]}]

# %%
import json

print json.dumps(world_trends, indent=1)
print
print json.dumps(us_trends, indent=1)
# Out:
# [
#  {
#   "created_at": "2014-10-09T02:52:53Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%22Kathy+Bates%22",
#     "query": "%22Kathy+Bates%22",
#     "name": "Kathy Bates",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23QueLindoSeria",
#     "query": "%23QueLindoSeria",
#     "name": "#QueLindoSeria",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LoQueMeRePuedeEs",
#     "query": "%23LoQueMeRePuedeEs",
#     "name": "#LoQueMeRePuedeEs",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AHSFX",
#     "query": "%23AHSFX",
#     "name": "#AHSFX",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TeJuroQue",
#     "query": "%23TeJuroQue",
#     "name": "#TeJuroQue",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Jimmy+Darlin%22",
#     "query": "%22Jimmy+Darlin%22",
#     "name": "Jimmy Darlin",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Tommy+Wingels%22",
#     "query": "%22Tommy+Wingels%22",
#     "name": "Tommy Wingels",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BrazilCantWaitToSeeFifthHarmony",
#     "query": "%23BrazilCantWaitToSeeFifthHarmony",
#     "name": "#BrazilCantWaitToSeeFifthHarmony",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Ethel",
#     "query": "Ethel",
#     "name": "Ethel",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Bette+and+Dot%22",
#     "query": "%22Bette+and+Dot%22",
#     "name": "Bette and Dot",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2014-10-09T02:56:53Z",
#   "locations": [
#    {
#     "woeid": 1,
#     "name": "Worldwide"
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "created_at": "2014-10-09T02:49:34Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23AHSFX",
#     "query": "%23AHSFX",
#     "name": "#AHSFX",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Twisty",
#     "query": "Twisty",
#     "name": "Twisty",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BetteAndDot",
#     "query": "%23BetteAndDot",
#     "name": "#BetteAndDot",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Key+%26+Peele%22",
#     "query": "%22Key+%26+Peele%22",
#     "name": "Key & Peele",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HalsteadsRage",
#     "query": "%23HalsteadsRage",
#     "name": "#HalsteadsRage",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Soliman",
#     "query": "Soliman",
#     "name": "Soliman",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ihateclowns",
#     "query": "%23ihateclowns",
#     "name": "#ihateclowns",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Evan+Peters%22",
#     "query": "%22Evan+Peters%22",
#     "name": "Evan Peters",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HollywoodDivas",
#     "query": "%23HollywoodDivas",
#     "name": "#HollywoodDivas",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Jermain+Taylor%22",
#     "query": "%22Jermain+Taylor%22",
#     "name": "Jermain Taylor",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2014-10-09T02:56:53Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ]
#  }
# ]

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print common_trends
# Out:
# set([u'#AHSFX'])

# %%
q = '#DataScience' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']

# print json.dumps(search_results, indent=1)
print json.dumps(statuses, indent=1)
# Out:
# [
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @amasoliverdilme: Experts Debate \u2018Building the Next Big App\u2019 [Part 1] https://t.co/FVVKZAuRce #datascience #bigdata #machinelearning",
#   "in_reply_to_status_id": null,
#   "id": 520044314714337280,
#   "favorite_count": 0,
#   "source": "<a href=\"http://www.simbasystems.com\" rel=\"nofollow\">NoSQLDigest</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 166645292,
#      "indices": [
#       3,
#       19
#      ],
#      "id_str": "166645292",
#      "screen_name": "amasoliverdilme",
#      "name": "Albert Masoliver"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       97,
#       109
#      ],
#      "text": "datascience"
#     },
#     {
#      "indices": [
#       110,
#       118
#      ],
#      "text": "bigdata"
#     },
#     {
#      "indices": [
#       119,
#       135
#      ],
#      "text": "machinelearning"
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/FVVKZAuRce",
#      "indices": [
#       73,
#       96
#      ],
#      "expanded_url": "https://twib.in/l/EzjyXnRobo7",
#      "display_url": "twib.in/l/EzjyXnRobo7"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 1,
#   "id_str": "520044314714337280",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Experts Debate \u2018Building the Next Big App\u2019 [Part 1] https://t.co/FVVKZAuRce #datascience #bigdata #machinelearning",
#    "in_reply_to_status_id": null,
#    "id": 520035467107254272,
#    "favorite_count": 1,
#    "source": "<a href=\"http://twibble.io\" rel=\"nofollow\">twibble.io</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [],
#     "hashtags": [
#      {
#       "indices": [
#        76,
#        88
#       ],
#       "text": "datascience"
#      },
#      {
#       "indices": [
#        89,
#        97
#       ],
#       "text": "bigdata"
#      },
#      {
#       "indices": [
#        98,
#        114
#       ],
#       "text": "machinelearning"
#      }
#     ],
#     "urls": [
#      {
#       "url": "https://t.co/FVVKZAuRce",
#       "indices": [
#        52,
#        75
#       ],
#       "expanded_url": "https://twib.in/l/EzjyXnRobo7",
#       "display_url": "twib.in/l/EzjyXnRobo7"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 1,
#    "id_str": "520035467107254272",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 166645292,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/500142748842745857/0Fxlfgjf_normal.jpeg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 231,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "166645292",
#     "profile_background_color": "C0DEED",
#     "listed_count": 6,
#     "is_translation_enabled": false,
#     "utc_offset": 7200,
#     "statuses_count": 2025,
#     "description": "Physicist and engineer. Passionate programmer. Data science researcher. Full-time dad, runner and mountaineer. #datascience #bigdata",
#     "friends_count": 121,
#     "location": "Barcelona",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/500142748842745857/0Fxlfgjf_normal.jpeg",
#     "following": false,
#     "geo_enabled": true,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/166645292/1408075743",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "amasoliverdilme",
#     "lang": "ca",
#     "profile_background_tile": false,
#     "favourites_count": 1799,
#     "name": "Albert Masoliver",
#     "notifications": false,
#     "url": null,
#     "created_at": "Wed Jul 14 17:29:06 +0000 2010",
#     "contributors_enabled": false,
#     "time_zone": "Madrid",
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Thu Oct 09 02:18:11 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 2704548373,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 1137,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "2704548373",
#    "profile_background_color": "C0DEED",
#    "listed_count": 56,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 56736,
#    "description": "NoSQL Digest of tweets.",
#    "friends_count": 11,
#    "location": "",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "NoSQLDigest",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 47,
#    "name": "NoSQL",
#    "notifications": false,
#    "url": null,
#    "created_at": "Sun Aug 03 17:07:24 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Oct 09 02:53:21 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @amasoliverdilme: The Value of Accuracy in Predictive Analytics https://t.co/j89yn5BRKv #analytics #datascience #bigdata",
#   "in_reply_to_status_id": null,
#   "id": 520043947431702528,
#   "favorite_count": 0,
#   "source": "<a href=\"http://www.simbasystems.com\" rel=\"nofollow\">NoSQLDigest</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 166645292,
#      "indices": [
#       3,
#       19
#      ],
#      "id_str": "166645292",
#      "screen_name": "amasoliverdilme",
#      "name": "Albert Masoliver"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       91,
#       101
#      ],
#      "text": "analytics"
#     },
#     {
#      "indices": [
#       102,
#       114
#      ],
#      "text": "datascience"
#     },
#     {
#      "indices": [
#       115,
#       123
#      ],
#      "text": "bigdata"
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/j89yn5BRKv",
#      "indices": [
#       67,
#       90
#      ],
#      "expanded_url": "https://twib.in/l/MAbKkAydpeM",
#      "display_url": "twib.in/l/MAbKkAydpeM"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 1,
#   "id_str": "520043947431702528",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "The Value of Accuracy in Predictive Analytics https://t.co/j89yn5BRKv #analytics #datascience #bigdata",
#    "in_reply_to_status_id": null,
#    "id": 520039325011279872,
#    "favorite_count": 2,
#    "source": "<a href=\"http://twibble.io\" rel=\"nofollow\">twibble.io</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [],
#     "hashtags": [
#      {
#       "indices": [
#        70,
#        80
#       ],
#       "text": "analytics"
#      },
#      {
#       "indices": [
#        81,
#        93
#       ],
#       "text": "datascience"
#      },
#      {
#       "indices": [
#        94,
#        102
#       ],
#       "text": "bigdata"
#      }
#     ],
#     "urls": [
#      {
#       "url": "https://t.co/j89yn5BRKv",
#       "indices": [
#        46,
#        69
#       ],
#       "expanded_url": "https://twib.in/l/MAbKkAydpeM",
#       "display_url": "twib.in/l/MAbKkAydpeM"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 1,
#    "id_str": "520039325011279872",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 166645292,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/500142748842745857/0Fxlfgjf_normal.jpeg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 231,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "166645292",
#     "profile_background_color": "C0DEED",
#     "listed_count": 6,
#     "is_translation_enabled": false,
#     "utc_offset": 7200,
#     "statuses_count": 2025,
#     "description": "Physicist and engineer. Passionate programmer. Data science researcher. Full-time dad, runner and mountaineer. #datascience #bigdata",
#     "friends_count": 121,
#     "location": "Barcelona",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/500142748842745857/0Fxlfgjf_normal.jpeg",
#     "following": false,
#     "geo_enabled": true,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/166645292/1408075743",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "amasoliverdilme",
#     "lang": "ca",
#     "profile_background_tile": false,
#     "favourites_count": 1799,
#     "name": "Albert Masoliver",
#     "notifications": false,
#     "url": null,
#     "created_at": "Wed Jul 14 17:29:06 +0000 2010",
#     "contributors_enabled": false,
#     "time_zone": "Madrid",
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Thu Oct 09 02:33:31 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 2704548373,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 1137,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "2704548373",
#    "profile_background_color": "C0DEED",
#    "listed_count": 56,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 56736,
#    "description": "NoSQL Digest of tweets.",
#    "friends_count": 11,
#    "location": "",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "NoSQLDigest",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 47,
#    "name": "NoSQL",
#    "notifications": false,
#    "url": null,
#    "created_at": "Sun Aug 03 17:07:24 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Oct 09 02:51:53 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @mjcavaretta: RT @cio__dp: What Technologies Work Best for Decentralized #DataScientists? #cio http://t.co/ozpD6hQy5c #bigdata #datascie\u2026",
#   "in_reply_to_status_id": null,
#   "id": 520043854590775296,
#   "favorite_count": 0,
#   "source": "<a href=\"http://www.simbasystems.com\" rel=\"nofollow\">NoSQLDigest</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 38670441,
#      "indices": [
#       3,
#       15
#      ],
#      "id_str": "38670441",
#      "screen_name": "mjcavaretta",
#      "name": "Michael Cavaretta"
#     },
#     {
#      "id": 2554222386,
#      "indices": [
#       20,
#       28
#      ],
#      "id_str": "2554222386",
#      "screen_name": "cio__dp",
#      "name": "CIO DP"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       76,
#       91
#      ],
#      "text": "DataScientists"
#     },
#     {
#      "indices": [
#       93,
#       97
#      ],
#      "text": "cio"
#     },
#     {
#      "indices": [
#       121,
#       129
#      ],
#      "text": "bigdata"
#     },
#     {
#      "indices": [
#       130,
#       140
#      ],
#      "text": "datascience"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/ozpD6hQy5c",
#      "indices": [
#       98,
#       120
#      ],
#      "expanded_url": "http://bit.ly/ZRcrCU",
#      "display_url": "bit.ly/ZRcrCU"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 4,
#   "id_str": "520043854590775296",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "RT @cio__dp: What Technologies Work Best for Decentralized #DataScientists? #cio http://t.co/ozpD6hQy5c #bigdata #datascience",
#    "in_reply_to_status_id": null,
#    "id": 520040125321846785,
#    "favorite_count": 1,
#    "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 2554222386,
#       "indices": [
#        3,
#        11
#       ],
#       "id_str": "2554222386",
#       "screen_name": "cio__dp",
#       "name": "CIO DP"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        59,
#        74
#       ],
#       "text": "DataScientists"
#      },
#      {
#       "indices": [
#        76,
#        80
#       ],
#       "text": "cio"
#      },
#      {
#       "indices": [
#        104,
#        112
#       ],
#       "text": "bigdata"
#      },
#      {
#       "indices": [
#        113,
#        125
#       ],
#       "text": "datascience"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/ozpD6hQy5c",
#       "indices": [
#        81,
#        103
#       ],
#       "expanded_url": "http://bit.ly/ZRcrCU",
#       "display_url": "bit.ly/ZRcrCU"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 4,
#    "id_str": "520040125321846785",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 38670441,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme18/bg.gif",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/3641511865/06a74914910ecfbcf220979136ba34f8_normal.jpeg",
#     "profile_sidebar_fill_color": "F6F6F6",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "http://t.co/a5J7LFnrgP",
#         "indices": [
#          0,
#          22
#         ],
#         "expanded_url": "http://www.linkedin.com/profile/view?id=17616353&trk=hb_tab_pro_top",
#         "display_url": "linkedin.com/profile/view?i\u2026"
#        }
#       ]
#      },
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 5023,
#     "profile_sidebar_border_color": "EEEEEE",
#     "id_str": "38670441",
#     "profile_background_color": "ACDED6",
#     "listed_count": 317,
#     "is_translation_enabled": false,
#     "utc_offset": -10800,
#     "statuses_count": 7445,
#     "description": "#DataScience Leader - Ford Motor Co. #BigData, #DataViz, #IoT. Opinions are my own. Top Big Data Influencer / Speaker - Da mihi omnibus notitia",
#     "friends_count": 1786,
#     "location": "Michigan",
#     "profile_link_color": "038543",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/3641511865/06a74914910ecfbcf220979136ba34f8_normal.jpeg",
#     "following": false,
#     "geo_enabled": false,
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme18/bg.gif",
#     "screen_name": "mjcavaretta",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 664,
#     "name": "Michael Cavaretta",
#     "notifications": false,
#     "url": "http://t.co/a5J7LFnrgP",
#     "created_at": "Fri May 08 14:00:01 +0000 2009",
#     "contributors_enabled": false,
#     "time_zone": "Atlantic Time (Canada)",
#     "protected": false,
#     "default_profile": false,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Thu Oct 09 02:36:42 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 2704548373,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 1137,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "2704548373",
#    "profile_background_color": "C0DEED",
#    "listed_count": 56,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 56736,
#    "description": "NoSQL Digest of tweets.",
#    "friends_count": 11,
#    "location": "",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "NoSQLDigest",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 47,
#    "name": "NoSQL",
#    "notifications": false,
#    "url": null,
#    "created_at": "Sun Aug 03 17:07:24 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Oct 09 02:51:31 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @mjcavaretta: RT @cio__dp: What Technologies Work Best for Decentralized #DataScientists? #cio http://t.co/ozpD6hQy5c #bigdata #datascie\u2026",
#   "in_reply_to_status_id": null,
#   "id": 520043488839483393,
#   "favorite_count": 0,
#   "source": "<a href=\"https://roundteam.co\" rel=\"nofollow\">RoundTeam</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 38670441,
#      "indices": [
#       3,
#       15
#      ],
#      "id_str": "38670441",
#      "screen_name": "mjcavaretta",
#      "name": "Michael Cavaretta"
#     },
#     {
#      "id": 2554222386,
#      "indices": [
#       20,
#       28
#      ],
#      "id_str": "2554222386",
#      "screen_name": "cio__dp",
#      "name": "CIO DP"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       76,
#       91
#      ],
#      "text": "DataScientists"
#     },
#     {
#      "indices": [
#       93,
#       97
#      ],
#      "text": "cio"
#     },
#     {
#      "indices": [
#       121,
#       129
#      ],
#      "text": "bigdata"
#     },
#     {
#      "indices": [
#       130,
#       140
#      ],
#      "text": "datascience"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/ozpD6hQy5c",
#      "indices": [
#       98,
#       120
#      ],
#      "expanded_url": "http://bit.ly/ZRcrCU",
#      "display_url": "bit.ly/ZRcrCU"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 4,
#   "id_str": "520043488839483393",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "RT @cio__dp: What Technologies Work Best for Decentralized #DataScientists? #cio http://t.co/ozpD6hQy5c #bigdata #datascience",
#    "in_reply_to_status_id": null,
#    "id": 520040125321846785,
#    "favorite_count": 1,
#    "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 2554222386,
#       "indices": [
#        3,
#        11
#       ],
#       "id_str": "2554222386",
#       "screen_name": "cio__dp",
#       "name": "CIO DP"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        59,
#        74
#       ],
#       "text": "DataScientists"
#      },
#      {
#       "indices": [
#        76,
#        80
#       ],
#       "text": "cio"
#      },
#      {
#       "indices": [
#        104,
#        112
#       ],
#       "text": "bigdata"
#      },
#      {
#       "indices": [
#        113,
#        125
#       ],
#       "text": "datascience"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/ozpD6hQy5c",
#       "indices": [
#        81,
#        103
#       ],
#       "expanded_url": "http://bit.ly/ZRcrCU",
#       "display_url": "bit.ly/ZRcrCU"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 4,
#    "id_str": "520040125321846785",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 38670441,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme18/bg.gif",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/3641511865/06a74914910ecfbcf220979136ba34f8_normal.jpeg",
#     "profile_sidebar_fill_color": "F6F6F6",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "http://t.co/a5J7LFnrgP",
#         "indices": [
#          0,
#          22
#         ],
#         "expanded_url": "http://www.linkedin.com/profile/view?id=17616353&trk=hb_tab_pro_top",
#         "display_url": "linkedin.com/profile/view?i\u2026"
#        }
#       ]
#      },
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 5023,
#     "profile_sidebar_border_color": "EEEEEE",
#     "id_str": "38670441",
#     "profile_background_color": "ACDED6",
#     "listed_count": 317,
#     "is_translation_enabled": false,
#     "utc_offset": -10800,
#     "statuses_count": 7445,
#     "description": "#DataScience Leader - Ford Motor Co. #BigData, #DataViz, #IoT. Opinions are my own. Top Big Data Influencer / Speaker - Da mihi omnibus notitia",
#     "friends_count": 1786,
#     "location": "Michigan",
#     "profile_link_color": "038543",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/3641511865/06a74914910ecfbcf220979136ba34f8_normal.jpeg",
#     "following": false,
#     "geo_enabled": false,
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme18/bg.gif",
#     "screen_name": "mjcavaretta",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 664,
#     "name": "Michael Cavaretta",
#     "notifications": false,
#     "url": "http://t.co/a5J7LFnrgP",
#     "created_at": "Fri May 08 14:00:01 +0000 2009",
#     "contributors_enabled": false,
#     "time_zone": "Atlantic Time (Canada)",
#     "protected": false,
#     "default_profile": false,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Thu Oct 09 02:36:42 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 380786715,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000486159808/6c9dde8644d6d07e6a0616b5116b94eb_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/V8aejBVdt5",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.mindcommerce.com",
#        "display_url": "mindcommerce.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 1160,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "380786715",
#    "profile_background_color": "C0DEED",
#    "listed_count": 70,
#    "is_translation_enabled": false,
#    "utc_offset": 10800,
#    "statuses_count": 93377,
#    "description": "Sales Executive - Mind Commerce Publishing\r\n#Telecom #RFID #M2M #NFC #Broadband #LBS #BigData #Mobile #Wireless #Network #SmartGrid #WiFi #WiMAX",
#    "friends_count": 1170,
#    "location": "",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/378800000486159808/6c9dde8644d6d07e6a0616b5116b94eb_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "jackwmson",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 13,
#    "name": "Jack Williamson",
#    "notifications": false,
#    "url": "http://t.co/V8aejBVdt5",
#    "created_at": "Tue Sep 27 07:06:24 +0000 2011",
#    "contributors_enabled": false,
#    "time_zone": "Athens",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Oct 09 02:50:04 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @BigDataNewsco: #Social #DataScience @SocialNewsCorp http://t.co/of2fUbqTKL Via #Twitter @janicemorphet @xvedamedia",
#   "in_reply_to_status_id": null,
#   "id": 520042971358449664,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 1522698907,
#      "indices": [
#       3,
#       17
#      ],
#      "id_str": "1522698907",
#      "screen_name": "BigDataNewsco",
#      "name": "Big Data News\u2122"
#     },
#     {
#      "id": 103044858,
#      "indices": [
#       40,
#       55
#      ],
#      "id_str": "103044858",
#      "screen_name": "SocialNewsCorp",
#      "name": "Mike Martino"
#     },
#     {
#      "id": 367718336,
#      "indices": [
#       92,
#       106
#      ],
#      "id_str": "367718336",
#      "screen_name": "janicemorphet",
#      "name": "Janice Morphet"
#     },
#     {
#      "id": 2353917925,
#      "indices": [
#       107,
#       118
#      ],
#      "id_str": "2353917925",
#      "screen_name": "xvedamedia",
#      "name": "Brandi Sanskrit"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       19,
#       26
#      ],
#      "text": "Social"
#     },
#     {
#      "indices": [
#       27,
#       39
#      ],
#      "text": "DataScience"
#     },
#     {
#      "indices": [
#       83,
#       91
#      ],
#      "text": "Twitter"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/of2fUbqTKL",
#      "indices": [
#       56,
#       78
#      ],
#      "expanded_url": "http://paper.li/BigDataNewsco/1385863608",
#      "display_url": "paper.li/BigDataNewsco/\u2026"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 1,
#   "id_str": "520042971358449664",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "#Social #DataScience @SocialNewsCorp http://t.co/of2fUbqTKL Via #Twitter @janicemorphet @xvedamedia",
#    "in_reply_to_status_id": null,
#    "id": 520018193214357505,
#    "favorite_count": 0,
#    "source": "<a href=\"http://paper.li\" rel=\"nofollow\">Paper.li</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 103044858,
#       "indices": [
#        21,
#        36
#       ],
#       "id_str": "103044858",
#       "screen_name": "SocialNewsCorp",
#       "name": "Mike Martino"
#      },
#      {
#       "id": 367718336,
#       "indices": [
#        73,
#        87
#       ],
#       "id_str": "367718336",
#       "screen_name": "janicemorphet",
#       "name": "Janice Morphet"
#      },
#      {
#       "id": 2353917925,
#       "indices": [
#        88,
#        99
#       ],
#       "id_str": "2353917925",
#       "screen_name": "xvedamedia",
#       "name": "Brandi Sanskrit"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        0,
#        7
#       ],
#       "text": "Social"
#      },
#      {
#       "indices": [
#        8,
#        20
#       ],
#       "text": "DataScience"
#      },
#      {
#       "indices": [
#        64,
#        72
#       ],
#       "text": "Twitter"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/of2fUbqTKL",
#       "indices": [
#        37,
#        59
#       ],
#       "expanded_url": "http://paper.li/BigDataNewsco/1385863608",
#       "display_url": "paper.li/BigDataNewsco/\u2026"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 1,
#    "id_str": "520018193214357505",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 1522698907,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000002090548/af34972d05b246b1be01c5cdb02f2e03_normal.png",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "http://t.co/dj1dHdrvVE",
#         "indices": [
#          0,
#          22
#         ],
#         "expanded_url": "http://BigDataNews.co",
#         "display_url": "BigDataNews.co"
#        }
#       ]
#      },
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 1683,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "1522698907",
#     "profile_background_color": "C0DEED",
#     "listed_count": 69,
#     "is_translation_enabled": false,
#     "utc_offset": -25200,
#     "statuses_count": 2842,
#     "description": "Big Data News Company\u2122 #bigdata #mobile #digital #media #socialnews #Agency @SocialNewsCorp #SocialMedia #News #marketing #analytics #healthcare #retail #data!",
#     "friends_count": 2056,
#     "location": "San Francisco CA. USA",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/378800000002090548/af34972d05b246b1be01c5cdb02f2e03_normal.png",
#     "following": false,
#     "geo_enabled": false,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1522698907/1371402447",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "BigDataNewsco",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 35,
#     "name": "Big Data News\u2122",
#     "notifications": false,
#     "url": "http://t.co/dj1dHdrvVE",
#     "created_at": "Sun Jun 16 17:00:00 +0000 2013",
#     "contributors_enabled": false,
#     "time_zone": "Pacific Time (US & Canada)",
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "und",
#    "created_at": "Thu Oct 09 01:09:33 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "und",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 103044858,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme13/bg.gif",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/508709185182117888/7T5k6j7__normal.jpeg",
#    "profile_sidebar_fill_color": "FFFFFF",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/XEcwZth47e",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://about.me/mikemartino",
#        "display_url": "about.me/mikemartino"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 12726,
#    "profile_sidebar_border_color": "EEEEEE",
#    "id_str": "103044858",
#    "profile_background_color": "B2DFDA",
#    "listed_count": 303,
#    "is_translation_enabled": false,
#    "utc_offset": -25200,
#    "statuses_count": 203592,
#    "description": "#Founder Social News Corp.\u2122 #international #digital #social #media #news #network #breaking #worldnews in real-time! #mobile #film #tv #radio #music #pr #travel",
#    "friends_count": 12316,
#    "location": "#Global #Social #News #Network",
#    "profile_link_color": "93A644",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/508709185182117888/7T5k6j7__normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/103044858/1348662295",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme13/bg.gif",
#    "screen_name": "SocialNewsCorp",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 2790,
#    "name": "Mike Martino",
#    "notifications": false,
#    "url": "http://t.co/XEcwZth47e",
#    "created_at": "Fri Jan 08 17:54:50 +0000 2010",
#    "contributors_enabled": false,
#    "time_zone": "Pacific Time (US & Canada)",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "und",
#   "created_at": "Thu Oct 09 02:48:00 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "und",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "New batch of 34 selected resources and articl... https://t.co/mzAPxsiIZ2 #analytics #machinelearning #datascience",
#   "in_reply_to_status_id": null,
#   "id": 520042970796818432,
#   "favorite_count": 1,
#   "source": "<a href=\"http://twibble.io\" rel=\"nofollow\">twibble.io</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       73,
#       83
#      ],
#      "text": "analytics"
#     },
#     {
#      "indices": [
#       84,
#       100
#      ],
#      "text": "machinelearning"
#     },
#     {
#      "indices": [
#       101,
#       113
#      ],
#      "text": "datascience"
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/mzAPxsiIZ2",
#      "indices": [
#       49,
#       72
#      ],
#      "expanded_url": "https://twib.in/l/qEakAjpLxoy",
#      "display_url": "twib.in/l/qEakAjpLxoy"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "520042970796818432",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 166645292,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/500142748842745857/0Fxlfgjf_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 231,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "166645292",
#    "profile_background_color": "C0DEED",
#    "listed_count": 6,
#    "is_translation_enabled": false,
#    "utc_offset": 7200,
#    "statuses_count": 2025,
#    "description": "Physicist and engineer. Passionate programmer. Data science researcher. Full-time dad, runner and mountaineer. #datascience #bigdata",
#    "friends_count": 121,
#    "location": "Barcelona",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/500142748842745857/0Fxlfgjf_normal.jpeg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/166645292/1408075743",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "amasoliverdilme",
#    "lang": "ca",
#    "profile_background_tile": false,
#    "favourites_count": 1799,
#    "name": "Albert Masoliver",
#    "notifications": false,
#    "url": null,
#    "created_at": "Wed Jul 14 17:29:06 +0000 2010",
#    "contributors_enabled": false,
#    "time_zone": "Madrid",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Oct 09 02:48:00 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "Why speed matters to #BigData &amp; #Analytics http://t.co/Edd10i7pCr  #datascience",
#   "in_reply_to_status_id": null,
#   "id": 520042788751413248,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       21,
#       29
#      ],
#      "text": "BigData"
#     },
#     {
#      "indices": [
#       36,
#       46
#      ],
#      "text": "Analytics"
#     },
#     {
#      "indices": [
#       71,
#       83
#      ],
#      "text": "datascience"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/Edd10i7pCr",
#      "indices": [
#       47,
#       69
#      ],
#      "expanded_url": "http://ibm.co/1oSw2Iv",
#      "display_url": "ibm.co/1oSw2Iv"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "520042788751413248",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 323191980,
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000106939247/e8e177f56f4185d5b498fe5ab8c56cd1.jpeg",
#    "verified": false,
#    "profile_text_color": "66646D",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/2973510158/e58d9ebcd6c74febe98524706485b68e_normal.jpeg",
#    "profile_sidebar_fill_color": "F9FAFA",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/P2I65ZkwEe",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://CamacConsulting.tumblr.com/",
#        "display_url": "CamacConsulting.tumblr.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 61889,
#    "profile_sidebar_border_color": "FFFFFF",
#    "id_str": "323191980",
#    "profile_background_color": "191B1C",
#    "listed_count": 23,
#    "is_translation_enabled": false,
#    "utc_offset": -25200,
#    "statuses_count": 4442,
#    "description": "We Enhance Organizational Performance. Analytics | Leadership | Strategy | Teamwork #MSMary, #Northwestern, #PennState",
#    "friends_count": 56,
#    "location": "Global",
#    "profile_link_color": "0ABDBD",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/2973510158/e58d9ebcd6c74febe98524706485b68e_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/323191980/1359771712",
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000106939247/e8e177f56f4185d5b498fe5ab8c56cd1.jpeg",
#    "screen_name": "CamacConsulting",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 3670,
#    "name": "Camac Consulting",
#    "notifications": false,
#    "url": "http://t.co/P2I65ZkwEe",
#    "created_at": "Fri Jun 24 12:19:49 +0000 2011",
#    "contributors_enabled": false,
#    "time_zone": "Pacific Time (US & Canada)",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Oct 09 02:47:17 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @mjcavaretta: RT @cio__dp: What Technologies Work Best for Decentralized #DataScientists? #cio http://t.co/ozpD6hQy5c #bigdata #datascie\u2026",
#   "in_reply_to_status_id": null,
#   "id": 520042540456636416,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 38670441,
#      "indices": [
#       3,
#       15
#      ],
#      "id_str": "38670441",
#      "screen_name": "mjcavaretta",
#      "name": "Michael Cavaretta"
#     },
#     {
#      "id": 2554222386,
#      "indices": [
#       20,
#       28
#      ],
#      "id_str": "2554222386",
#      "screen_name": "cio__dp",
#      "name": "CIO DP"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       76,
#       91
#      ],
#      "text": "DataScientists"
#     },
#     {
#      "indices": [
#       93,
#       97
#      ],
#      "text": "cio"
#     },
#     {
#      "indices": [
#       121,
#       129
#      ],
#      "text": "bigdata"
#     },
#     {
#      "indices": [
#       130,
#       140
#      ],
#      "text": "datascience"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/ozpD6hQy5c",
#      "indices": [
#       98,
#       120
#      ],
#      "expanded_url": "http://bit.ly/ZRcrCU",
#      "display_url": "bit.ly/ZRcrCU"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 4,
#   "id_str": "520042540456636416",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "RT @cio__dp: What Technologies Work Best for Decentralized #DataScientists? #cio http://t.co/ozpD6hQy5c #bigdata #datascience",
#    "in_reply_to_status_id": null,
#    "id": 520040125321846785,
#    "favorite_count": 1,
#    "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 2554222386,
#       "indices": [
#        3,
#        11
#       ],
#       "id_str": "2554222386",
#       "screen_name": "cio__dp",
#       "name": "CIO DP"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        59,
#        74
#       ],
#       "text": "DataScientists"
#      },
#      {
#       "indices": [
#        76,
#        80
#       ],
#       "text": "cio"
#      },
#      {
#       "indices": [
#        104,
#        112
#       ],
#       "text": "bigdata"
#      },
#      {
#       "indices": [
#        113,
#        125
#       ],
#       "text": "datascience"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/ozpD6hQy5c",
#       "indices": [
#        81,
#        103
#       ],
#       "expanded_url": "http://bit.ly/ZRcrCU",
#       "display_url": "bit.ly/ZRcrCU"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 4,
#    "id_str": "520040125321846785",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 38670441,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme18/bg.gif",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/3641511865/06a74914910ecfbcf220979136ba34f8_normal.jpeg",
#     "profile_sidebar_fill_color": "F6F6F6",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "http://t.co/a5J7LFnrgP",
#         "indices": [
#          0,
#          22
#         ],
#         "expanded_url": "http://www.linkedin.com/profile/view?id=17616353&trk=hb_tab_pro_top",
#         "display_url": "linkedin.com/profile/view?i\u2026"
#        }
#       ]
#      },
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 5023,
#     "profile_sidebar_border_color": "EEEEEE",
#     "id_str": "38670441",
#     "profile_background_color": "ACDED6",
#     "listed_count": 317,
#     "is_translation_enabled": false,
#     "utc_offset": -10800,
#     "statuses_count": 7445,
#     "description": "#DataScience Leader - Ford Motor Co. #BigData, #DataViz, #IoT. Opinions are my own. Top Big Data Influencer / Speaker - Da mihi omnibus notitia",
#     "friends_count": 1786,
#     "location": "Michigan",
#     "profile_link_color": "038543",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/3641511865/06a74914910ecfbcf220979136ba34f8_normal.jpeg",
#     "following": false,
#     "geo_enabled": false,
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme18/bg.gif",
#     "screen_name": "mjcavaretta",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 664,
#     "name": "Michael Cavaretta",
#     "notifications": false,
# ...
#     "following": false,
#     "geo_enabled": true,
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#     "screen_name": "tonyojeda3",
#     "lang": "en",
#     "profile_background_tile": true,
#     "favourites_count": 64,
#     "name": "Tony Ojeda",
#     "notifications": false,
#     "url": "http://t.co/5j4LMsuwJb",
#     "created_at": "Sat Jun 06 01:11:16 +0000 2009",
#     "contributors_enabled": false,
#     "time_zone": "Eastern Time (US & Canada)",
#     "protected": false,
#     "default_profile": false,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Wed Oct 08 23:45:01 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 2704548373,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 1137,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "2704548373",
#    "profile_background_color": "C0DEED",
#    "listed_count": 56,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 56736,
#    "description": "NoSQL Digest of tweets.",
#    "friends_count": 11,
#    "location": "",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "NoSQLDigest",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 47,
#    "name": "NoSQL",
#    "notifications": false,
#    "url": null,
#    "created_at": "Sun Aug 03 17:07:24 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Wed Oct 08 23:53:28 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @CCAlvord: Nerding out about technology. #relateiq #datascience @dpatil http://t.co/FNrDUgiajT",
#   "in_reply_to_status_id": null,
#   "id": 519998964238934017,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 217439425,
#      "indices": [
#       3,
#       12
#      ],
#      "id_str": "217439425",
#      "screen_name": "CCAlvord",
#      "name": "Cici Alvord"
#     },
#     {
#      "id": 14839109,
#      "indices": [
#       67,
#       74
#      ],
#      "id_str": "14839109",
#      "screen_name": "dpatil",
#      "name": "dj patil"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       44,
#       53
#      ],
#      "text": "relateiq"
#     },
#     {
#      "indices": [
#       54,
#       66
#      ],
#      "text": "datascience"
#     }
#    ],
#    "urls": [],
#    "media": [
#     {
#      "source_status_id_str": "519967598256353280",
#      "expanded_url": "http://twitter.com/CCAlvord/status/519967598256353280/photo/1",
#      "display_url": "pic.twitter.com/FNrDUgiajT",
#      "url": "http://t.co/FNrDUgiajT",
#      "media_url_https": "https://pbs.twimg.com/media/BzdLxogIUAAe8CC.jpg",
#      "source_status_id": 519967598256353280,
#      "id_str": "519967598042435584",
#      "sizes": {
#       "small": {
#        "h": 193,
#        "resize": "fit",
#        "w": 340
#       },
#       "large": {
#        "h": 584,
#        "resize": "fit",
#        "w": 1024
#       },
#       "medium": {
#        "h": 342,
#        "resize": "fit",
#        "w": 600
#       },
#       "thumb": {
#        "h": 150,
#        "resize": "crop",
#        "w": 150
#       }
#      },
#      "indices": [
#       75,
#       97
#      ],
#      "type": "photo",
#      "id": 519967598042435584,
#      "media_url": "http://pbs.twimg.com/media/BzdLxogIUAAe8CC.jpg"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 1,
#   "id_str": "519998964238934017",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Nerding out about technology. #relateiq #datascience @dpatil http://t.co/FNrDUgiajT",
#    "in_reply_to_status_id": null,
#    "id": 519967598256353280,
#    "favorite_count": 4,
#    "source": "<a href=\"http://www.apple.com\" rel=\"nofollow\">iOS</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 14839109,
#       "indices": [
#        53,
#        60
#       ],
#       "id_str": "14839109",
#       "screen_name": "dpatil",
#       "name": "dj patil"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        30,
#        39
#       ],
#       "text": "relateiq"
#      },
#      {
#       "indices": [
#        40,
#        52
#       ],
#       "text": "datascience"
#      }
#     ],
#     "urls": [],
#     "media": [
#      {
#       "expanded_url": "http://twitter.com/CCAlvord/status/519967598256353280/photo/1",
#       "display_url": "pic.twitter.com/FNrDUgiajT",
#       "url": "http://t.co/FNrDUgiajT",
#       "media_url_https": "https://pbs.twimg.com/media/BzdLxogIUAAe8CC.jpg",
#       "id_str": "519967598042435584",
#       "sizes": {
#        "small": {
#         "h": 193,
#         "resize": "fit",
#         "w": 340
#        },
#        "large": {
#         "h": 584,
#         "resize": "fit",
#         "w": 1024
#        },
#        "medium": {
#         "h": 342,
#         "resize": "fit",
#         "w": 600
#        },
#        "thumb": {
#         "h": 150,
#         "resize": "crop",
#         "w": 150
#        }
#       },
#       "indices": [
#        61,
#        83
#       ],
#       "type": "photo",
#       "id": 519967598042435584,
#       "media_url": "http://pbs.twimg.com/media/BzdLxogIUAAe8CC.jpg"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 1,
#    "id_str": "519967598256353280",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 217439425,
#     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/173216353/x9af4dfc8f3ae07667c1a633fce48c3f.jpg",
#     "verified": false,
#     "profile_text_color": "C6E4C8",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/423310436901994498/ep7WpM_S_normal.jpeg",
#     "profile_sidebar_fill_color": "3B6980",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "http://t.co/sojHC3k9Pl",
#         "indices": [
#          0,
#          22
#         ],
#         "expanded_url": "http://about.me/cicia",
#         "display_url": "about.me/cicia"
#        }
#       ]
#      },
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 324,
#     "profile_sidebar_border_color": "40485D",
#     "id_str": "217439425",
#     "profile_background_color": "E1E6B0",
#     "listed_count": 13,
#     "is_translation_enabled": false,
#     "utc_offset": -25200,
#     "statuses_count": 1686,
#     "description": "Recruiting Professional, goofball, proud Swede, runner, skier and cyclist. Lover of dogs and tech.",
#     "friends_count": 599,
#     "location": "San Francisco, CA",
#     "profile_link_color": "91C7B9",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/423310436901994498/ep7WpM_S_normal.jpeg",
#     "following": false,
#     "geo_enabled": true,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/217439425/1389760148",
#     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/173216353/x9af4dfc8f3ae07667c1a633fce48c3f.jpg",
#     "screen_name": "CCAlvord",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 50,
#     "name": "Cici Alvord",
#     "notifications": false,
#     "url": "http://t.co/sojHC3k9Pl",
#     "created_at": "Fri Nov 19 14:51:11 +0000 2010",
#     "contributors_enabled": false,
#     "time_zone": "Pacific Time (US & Canada)",
#     "protected": false,
#     "default_profile": false,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Wed Oct 08 21:48:30 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 14839109,
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/479890002/x075c8f3b9861f0560401c02f8627e02.jpg",
#    "verified": false,
#    "profile_text_color": "6C961C",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/2827560897/e76b7577f7d9545362b9fb65c9db3bb3_normal.png",
#    "profile_sidebar_fill_color": "3E789C",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/PHMrzlAGlq",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.linkedin.com/in/dpatil",
#        "display_url": "linkedin.com/in/dpatil"
#       }
#      ]
#     },
#     "description": {
#      "urls": [
#       {
#        "url": "http://t.co/dSmraQqqRv",
#        "indices": [
#         32,
#         54
#        ],
#        "expanded_url": "http://www.relateiq.com",
#        "display_url": "relateiq.com"
#       }
#      ]
#     }
#    },
#    "followers_count": 19415,
#    "profile_sidebar_border_color": "E2EAEF",
#    "id_str": "14839109",
#    "profile_background_color": "DADDC0",
#    "listed_count": 1045,
#    "is_translation_enabled": false,
#    "utc_offset": -25200,
#    "statuses_count": 9844,
#    "description": "Building products at RelateIQ - http://t.co/dSmraQqqRv",
#    "friends_count": 973,
#    "location": "Silicon Valley",
#    "profile_link_color": "877F63",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/2827560897/e76b7577f7d9545362b9fb65c9db3bb3_normal.png",
#    "following": false,
#    "geo_enabled": true,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/14839109/1404835991",
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/479890002/x075c8f3b9861f0560401c02f8627e02.jpg",
#    "screen_name": "dpatil",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 5073,
#    "name": "dj patil",
#    "notifications": false,
#    "url": "http://t.co/PHMrzlAGlq",
#    "created_at": "Mon May 19 23:31:12 +0000 2008",
#    "contributors_enabled": false,
#    "time_zone": "Pacific Time (US & Canada)",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Wed Oct 08 23:53:08 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "Plan Your Next Move in Advanced #Analytics \u2014 #BigData #DataScience is your future! http://t.co/pxdHSvnh4W | HT @DiegoKuonen",
#   "in_reply_to_status_id": null,
#   "id": 519998963751976960,
#   "favorite_count": 0,
#   "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 2214285223,
#      "indices": [
#       111,
#       123
#      ],
#      "id_str": "2214285223",
#      "screen_name": "DiegoKuonen",
#      "name": "Dr. Diego Kuonen"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       32,
#       42
#      ],
#      "text": "Analytics"
#     },
#     {
#      "indices": [
#       45,
#       53
#      ],
#      "text": "BigData"
#     },
#     {
#      "indices": [
#       54,
#       66
#      ],
#      "text": "DataScience"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/pxdHSvnh4W",
#      "indices": [
#       83,
#       105
#      ],
#      "expanded_url": "http://en.community.dell.com/techcenter/information-management/b/weblog/archive/2014/10/08/hurwitz-report-plan-your-next-move-in-advanced-analytics",
#      "display_url": "en.community.dell.com/techcenter/inf\u2026"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 3,
#   "id_str": "519998963751976960",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 534563976,
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000110442114/094a0b4d38b70e3871a1bda7d7fe2341.jpeg",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/452157174769524737/cknjYfAC_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/tWlmevaWIF",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.linkedin.com/in/kirkdborne",
#        "display_url": "linkedin.com/in/kirkdborne"
#       }
#      ]
#     },
#     "description": {
#      "urls": [
#       {
#        "url": "http://t.co/qYn8bft1fP",
#        "indices": [
#         130,
#         152
#        ],
#        "expanded_url": "http://kirkborne.net/",
#        "display_url": "kirkborne.net"
#       }
#      ]
#     }
#    },
#    "followers_count": 16455,
#    "profile_sidebar_border_color": "FFFFFF",
#    "id_str": "534563976",
#    "profile_background_color": "C0DEED",
#    "listed_count": 824,
#    "is_translation_enabled": false,
#    "utc_offset": -14400,
#    "statuses_count": 26988,
#    "description": "PhD DataScientist Astrophysicist, Top #BigData Influencer. Passions: #DataScience, #DataMining, Astroinformatics, #CitizenScience http://t.co/qYn8bft1fP",
#    "friends_count": 15330,
#    "location": "George Mason University",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/452157174769524737/cknjYfAC_normal.jpeg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/534563976/1355112691",
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000110442114/094a0b4d38b70e3871a1bda7d7fe2341.jpeg",
#    "screen_name": "KirkDBorne",
#    "lang": "en",
#    "profile_background_tile": true,
#    "favourites_count": 33884,
#    "name": "Kirk Borne",
#    "notifications": false,
#    "url": "http://t.co/tWlmevaWIF",
#    "created_at": "Fri Mar 23 16:35:17 +0000 2012",
#    "contributors_enabled": false,
#    "time_zone": "Eastern Time (US & Canada)",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Wed Oct 08 23:53:08 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  }
# ]

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print json.dumps(status_texts[0:5], indent=1)
print json.dumps(screen_names[0:5], indent=1) 
print json.dumps(hashtags[0:5], indent=1)
print json.dumps(words[0:5], indent=1)
# Out:
# [
#  "RT @amasoliverdilme: Experts Debate \u2018Building the Next Big App\u2019 [Part 1] https://t.co/FVVKZAuRce #datascience #bigdata #machinelearning",
#  "RT @amasoliverdilme: The Value of Accuracy in Predictive Analytics https://t.co/j89yn5BRKv #analytics #datascience #bigdata",
#  "RT @mjcavaretta: RT @cio__dp: What Technologies Work Best for Decentralized #DataScientists? #cio http://t.co/ozpD6hQy5c #bigdata #datascie\u2026",
#  "RT @mjcavaretta: RT @cio__dp: What Technologies Work Best for Decentralized #DataScientists? #cio http://t.co/ozpD6hQy5c #bigdata #datascie\u2026",
#  "RT @BigDataNewsco: #Social #DataScience @SocialNewsCorp http://t.co/of2fUbqTKL Via #Twitter @janicemorphet @xvedamedia"
# ]
# [
#  "amasoliverdilme",
#  "amasoliverdilme",
#  "mjcavaretta",
#  "cio__dp",
#  "mjcavaretta"
# ]
# [
#  "datascience",
#  "bigdata",
#  "machinelearning",
#  "analytics",
#  "datascience"
# ]
# [
#  "RT",
#  "@amasoliverdilme:",
#  "Experts",
#  "Debate",
#  "\u2018Building"
# ]

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print c.most_common()[:10] # top 10
    print
# Out:
# [(u'RT', 73), (u'#datascience', 43), (u'#DataScience', 39), (u'#bigdata', 35), (u'#BigData', 28), (u'Data', 19), (u'of', 19), (u'the', 18), (u'#analytics', 15), (u'in', 14)]
#
# [(u'KirkDBorne', 11), (u'tonyojeda3', 9), (u'amasoliverdilme', 8), (u'Boundary2', 6), (u'mjcavaretta', 6), (u'cio__dp', 5), (u'dgolumbia', 5), (u'DiegoKuonen', 4), (u'Goko_Gorgiovski', 3), (u'DataCamp_com', 3)]
#
# [(u'datascience', 56), (u'DataScience', 44), (u'bigdata', 38), (u'BigData', 29), (u'analytics', 17), (u'Analytics', 14), (u'machinelearning', 11), (u'OKCupid', 6), (u'Python', 5), (u'DataScientists', 5)]

# %% [markdown]
# ### Exercise 2
# ##### What are the search results for #machinelearning?
# ##### Which words, screen_names and hashtags are most common?
#
# ### Bonus Questions
# ##### Which hashtags are most common between #machinelearning and #datascience?
# ##### Search the most popular data science hashtags and determine what topics are trending the most across the most popular data science hastags?
# ##### Determine the most prolific screen_names for data science and find out who they are?

# %%
q = '#machinelearning' 
count = 100
# See https://dev.twitter.com/docs/api/1.1/get/search/tweets
ml_search_results = twitter_api.search.tweets(q=q, count=count)
ml_statuses = ml_search_results['statuses']

# print json.dumps(search_results, indent=1)
print json.dumps(ml_statuses, indent=1)
# Out:
# [
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "Using Datumbox API with Ruby and Node.js: http://t.co/8C30FQmIAB #ruby #nodejs #machinelearning #api",
#   "in_reply_to_status_id": null,
#   "id": 520045997763092480,
#   "favorite_count": 1,
#   "source": "<a href=\"http://www.datumbox.com\" rel=\"nofollow\">Auto-Tweets-Datumbox</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       65,
#       70
#      ],
#      "text": "ruby"
#     },
#     {
#      "indices": [
#       71,
#       78
#      ],
#      "text": "nodejs"
#     },
#     {
#      "indices": [
#       79,
#       95
#      ],
#      "text": "machinelearning"
#     },
#     {
#      "indices": [
#       96,
#       100
#      ],
#      "text": "api"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/8C30FQmIAB",
#      "indices": [
#       42,
#       64
#      ],
#      "expanded_url": "http://blog.datumbox.com/using-datumbox-api-with-ruby-node-js-and-other-featured-projects/",
#      "display_url": "blog.datumbox.com/using-datumbox\u2026"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "520045997763092480",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 1569248167,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000382138054/8d77fba302efc79debdeea44a8f71322_normal.png",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/Nxjbmtfp0z",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.datumbox.com/",
#        "display_url": "datumbox.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 487,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "1569248167",
#    "profile_background_color": "C0DEED",
#    "listed_count": 45,
#    "is_translation_enabled": false,
#    "utc_offset": 3600,
#    "statuses_count": 7499,
#    "description": "Datumbox offers an innovative Machine Learning platform specialized in Natural Language Processing.",
#    "friends_count": 44,
#    "location": "",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/378800000382138054/8d77fba302efc79debdeea44a8f71322_normal.png",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "Datumbox",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 0,
#    "name": "Datumbox",
#    "notifications": false,
#    "url": "http://t.co/Nxjbmtfp0z",
#    "created_at": "Thu Jul 04 22:41:38 +0000 2013",
#    "contributors_enabled": false,
#    "time_zone": "London",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Oct 09 03:00:02 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @josephsirosh: Predict the 2014 U.S. Elections and more - at Microsoft Prediction Lab -- http://t.co/c8A3tlu9Kn  #MachineLearning #azure\u2026",
#   "in_reply_to_status_id": null,
#   "id": 520045246273847297,
#   "favorite_count": 0,
#   "source": "<a href=\"http://www.twitter.com\" rel=\"nofollow\">Twitter for Windows Phone</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 2485229282,
#      "indices": [
#       3,
#       16
#      ],
#      "id_str": "2485229282",
#      "screen_name": "josephsirosh",
#      "name": "Joseph Sirosh"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       116,
#       132
#      ],
#      "text": "MachineLearning"
#     },
#     {
#      "indices": [
#       133,
#       140
#      ],
#      "text": "azureml"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/c8A3tlu9Kn",
#      "indices": [
#       92,
#       114
#      ],
#      "expanded_url": "http://aka.ms/mrbmzn",
#      "display_url": "aka.ms/mrbmzn"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 9,
#   "id_str": "520045246273847297",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Predict the 2014 U.S. Elections and more - at Microsoft Prediction Lab -- http://t.co/c8A3tlu9Kn  #MachineLearning #azureml",
#    "in_reply_to_status_id": null,
#    "id": 520021451915550720,
#    "favorite_count": 3,
#    "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [],
#     "hashtags": [
#      {
#       "indices": [
#        98,
#        114
#       ],
#       "text": "MachineLearning"
#      },
#      {
#       "indices": [
#        115,
#        123
#       ],
#       "text": "azureml"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/c8A3tlu9Kn",
#       "indices": [
#        74,
#        96
#       ],
#       "expanded_url": "http://aka.ms/mrbmzn",
#       "display_url": "aka.ms/mrbmzn"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 9,
#    "id_str": "520021451915550720",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 2485229282,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/464737468311289856/UxDeSZ3B_normal.jpeg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 589,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "2485229282",
#     "profile_background_color": "C0DEED",
#     "listed_count": 8,
#     "is_translation_enabled": false,
#     "utc_offset": null,
#     "statuses_count": 64,
#     "description": "Passionate about machine learning, data science and the cloud.",
#     "friends_count": 134,
#     "location": "Bellevue, Washington",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/464737468311289856/UxDeSZ3B_normal.jpeg",
#     "following": false,
#     "geo_enabled": false,
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "josephsirosh",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 4,
#     "name": "Joseph Sirosh",
#     "notifications": false,
#     "url": null,
#     "created_at": "Fri May 09 11:43:57 +0000 2014",
#     "contributors_enabled": false,
#     "time_zone": null,
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Thu Oct 09 01:22:30 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 23139168,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1703595623/12th_man_normal.jpg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 54,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "23139168",
#    "profile_background_color": "C0DEED",
#    "listed_count": 1,
#    "is_translation_enabled": false,
#    "utc_offset": -28800,
#    "statuses_count": 557,
#    "description": "",
#    "friends_count": 298,
#    "location": "Sammamish, WA ",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1703595623/12th_man_normal.jpg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "jbinz",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 19,
#    "name": "Joe Binz",
#    "notifications": false,
#    "url": null,
#    "created_at": "Sat Mar 07 00:00:47 +0000 2009",
#    "contributors_enabled": false,
#    "time_zone": "Alaska",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Oct 09 02:57:03 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @amasoliverdilme: Experts Debate \u2018Building the Next Big App\u2019 [Part 1] https://t.co/FVVKZAuRce #datascience #bigdata #machinelearning",
#   "in_reply_to_status_id": null,
#   "id": 520044314714337280,
#   "favorite_count": 0,
#   "source": "<a href=\"http://www.simbasystems.com\" rel=\"nofollow\">NoSQLDigest</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 166645292,
#      "indices": [
#       3,
#       19
#      ],
#      "id_str": "166645292",
#      "screen_name": "amasoliverdilme",
#      "name": "Albert Masoliver"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       97,
#       109
#      ],
#      "text": "datascience"
#     },
#     {
#      "indices": [
#       110,
#       118
#      ],
#      "text": "bigdata"
#     },
#     {
#      "indices": [
#       119,
#       135
#      ],
#      "text": "machinelearning"
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/FVVKZAuRce",
#      "indices": [
#       73,
#       96
#      ],
#      "expanded_url": "https://twib.in/l/EzjyXnRobo7",
#      "display_url": "twib.in/l/EzjyXnRobo7"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 1,
#   "id_str": "520044314714337280",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Experts Debate \u2018Building the Next Big App\u2019 [Part 1] https://t.co/FVVKZAuRce #datascience #bigdata #machinelearning",
#    "in_reply_to_status_id": null,
#    "id": 520035467107254272,
#    "favorite_count": 1,
#    "source": "<a href=\"http://twibble.io\" rel=\"nofollow\">twibble.io</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [],
#     "hashtags": [
#      {
#       "indices": [
#        76,
#        88
#       ],
#       "text": "datascience"
#      },
#      {
#       "indices": [
#        89,
#        97
#       ],
#       "text": "bigdata"
#      },
#      {
#       "indices": [
#        98,
#        114
#       ],
#       "text": "machinelearning"
#      }
#     ],
#     "urls": [
#      {
#       "url": "https://t.co/FVVKZAuRce",
#       "indices": [
#        52,
#        75
#       ],
#       "expanded_url": "https://twib.in/l/EzjyXnRobo7",
#       "display_url": "twib.in/l/EzjyXnRobo7"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 1,
#    "id_str": "520035467107254272",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 166645292,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/500142748842745857/0Fxlfgjf_normal.jpeg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 231,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "166645292",
#     "profile_background_color": "C0DEED",
#     "listed_count": 6,
#     "is_translation_enabled": false,
#     "utc_offset": 7200,
#     "statuses_count": 2025,
#     "description": "Physicist and engineer. Passionate programmer. Data science researcher. Full-time dad, runner and mountaineer. #datascience #bigdata",
#     "friends_count": 121,
#     "location": "Barcelona",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/500142748842745857/0Fxlfgjf_normal.jpeg",
#     "following": false,
#     "geo_enabled": true,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/166645292/1408075743",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "amasoliverdilme",
#     "lang": "ca",
#     "profile_background_tile": false,
#     "favourites_count": 1799,
#     "name": "Albert Masoliver",
#     "notifications": false,
#     "url": null,
#     "created_at": "Wed Jul 14 17:29:06 +0000 2010",
#     "contributors_enabled": false,
#     "time_zone": "Madrid",
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Thu Oct 09 02:18:11 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 2704548373,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 1137,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "2704548373",
#    "profile_background_color": "C0DEED",
#    "listed_count": 56,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 56736,
#    "description": "NoSQL Digest of tweets.",
#    "friends_count": 11,
#    "location": "",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "NoSQLDigest",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 47,
#    "name": "NoSQL",
#    "notifications": false,
#    "url": null,
#    "created_at": "Sun Aug 03 17:07:24 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Oct 09 02:53:21 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "New batch of 34 selected resources and articl... https://t.co/mzAPxsiIZ2 #analytics #machinelearning #datascience",
#   "in_reply_to_status_id": null,
#   "id": 520042970796818432,
#   "favorite_count": 1,
#   "source": "<a href=\"http://twibble.io\" rel=\"nofollow\">twibble.io</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       73,
#       83
#      ],
#      "text": "analytics"
#     },
#     {
#      "indices": [
#       84,
#       100
#      ],
#      "text": "machinelearning"
#     },
#     {
#      "indices": [
#       101,
#       113
#      ],
#      "text": "datascience"
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/mzAPxsiIZ2",
#      "indices": [
#       49,
#       72
#      ],
#      "expanded_url": "https://twib.in/l/qEakAjpLxoy",
#      "display_url": "twib.in/l/qEakAjpLxoy"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "520042970796818432",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 166645292,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/500142748842745857/0Fxlfgjf_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 231,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "166645292",
#    "profile_background_color": "C0DEED",
#    "listed_count": 6,
#    "is_translation_enabled": false,
#    "utc_offset": 7200,
#    "statuses_count": 2025,
#    "description": "Physicist and engineer. Passionate programmer. Data science researcher. Full-time dad, runner and mountaineer. #datascience #bigdata",
#    "friends_count": 121,
#    "location": "Barcelona",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/500142748842745857/0Fxlfgjf_normal.jpeg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/166645292/1408075743",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "amasoliverdilme",
#    "lang": "ca",
#    "profile_background_tile": false,
#    "favourites_count": 1799,
#    "name": "Albert Masoliver",
#    "notifications": false,
#    "url": null,
#    "created_at": "Wed Jul 14 17:29:06 +0000 2010",
#    "contributors_enabled": false,
#    "time_zone": "Madrid",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Oct 09 02:48:00 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @josephsirosh: Predict the 2014 U.S. Elections and more - at Microsoft Prediction Lab -- http://t.co/c8A3tlu9Kn  #MachineLearning #azure\u2026",
#   "in_reply_to_status_id": null,
#   "id": 520040678601261056,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/#!/download/ipad\" rel=\"nofollow\">Twitter for iPad</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 2485229282,
#      "indices": [
#       3,
#       16
#      ],
#      "id_str": "2485229282",
#      "screen_name": "josephsirosh",
#      "name": "Joseph Sirosh"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       116,
#       132
#      ],
#      "text": "MachineLearning"
#     },
#     {
#      "indices": [
#       133,
#       140
#      ],
#      "text": "azureml"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/c8A3tlu9Kn",
#      "indices": [
#       92,
#       114
#      ],
#      "expanded_url": "http://aka.ms/mrbmzn",
#      "display_url": "aka.ms/mrbmzn"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 9,
#   "id_str": "520040678601261056",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Predict the 2014 U.S. Elections and more - at Microsoft Prediction Lab -- http://t.co/c8A3tlu9Kn  #MachineLearning #azureml",
#    "in_reply_to_status_id": null,
#    "id": 520021451915550720,
#    "favorite_count": 3,
#    "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [],
#     "hashtags": [
#      {
#       "indices": [
#        98,
#        114
#       ],
#       "text": "MachineLearning"
#      },
#      {
#       "indices": [
#        115,
#        123
#       ],
#       "text": "azureml"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/c8A3tlu9Kn",
#       "indices": [
#        74,
#        96
#       ],
#       "expanded_url": "http://aka.ms/mrbmzn",
#       "display_url": "aka.ms/mrbmzn"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 9,
#    "id_str": "520021451915550720",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 2485229282,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/464737468311289856/UxDeSZ3B_normal.jpeg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 589,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "2485229282",
#     "profile_background_color": "C0DEED",
#     "listed_count": 8,
#     "is_translation_enabled": false,
#     "utc_offset": null,
#     "statuses_count": 64,
#     "description": "Passionate about machine learning, data science and the cloud.",
#     "friends_count": 134,
#     "location": "Bellevue, Washington",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/464737468311289856/UxDeSZ3B_normal.jpeg",
#     "following": false,
#     "geo_enabled": false,
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "josephsirosh",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 4,
#     "name": "Joseph Sirosh",
#     "notifications": false,
#     "url": null,
#     "created_at": "Fri May 09 11:43:57 +0000 2014",
#     "contributors_enabled": false,
#     "time_zone": null,
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Thu Oct 09 01:22:30 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 35556117,
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/11244928/cv-bg-invert.jpg",
#    "verified": false,
#    "profile_text_color": "858585",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/3759442861/a5dd49336a20ae5c9cca42700138aaaa_normal.png",
#    "profile_sidebar_fill_color": "F5F5F5",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/DjWMrkSI1f",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.corvalius.com",
#        "display_url": "corvalius.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 1017,
#    "profile_sidebar_border_color": "000000",
#    "id_str": "35556117",
#    "profile_background_color": "FFFFFF",
#    "listed_count": 38,
#    "is_translation_enabled": false,
#    "utc_offset": -10800,
#    "statuses_count": 1677,
#    "description": "Software Research Outsourcing for Innovation. We go further than software development.",
#    "friends_count": 337,
#    "location": "Argentina",
#    "profile_link_color": "FF640A",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/3759442861/a5dd49336a20ae5c9cca42700138aaaa_normal.png",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/35556117/1370450971",
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/11244928/cv-bg-invert.jpg",
#    "screen_name": "Corvalius",
#    "lang": "en",
#    "profile_background_tile": true,
#    "favourites_count": 60,
#    "name": "Corvalius",
#    "notifications": false,
#    "url": "http://t.co/DjWMrkSI1f",
#    "created_at": "Sun Apr 26 20:28:41 +0000 2009",
#    "contributors_enabled": false,
#    "time_zone": "Buenos Aires",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Oct 09 02:38:54 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @josephsirosh: Predict the 2014 U.S. Elections and more - at Microsoft Prediction Lab -- http://t.co/c8A3tlu9Kn  #MachineLearning #azure\u2026",
#   "in_reply_to_status_id": null,
#   "id": 520039938277244928,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 2485229282,
#      "indices": [
#       3,
#       16
#      ],
#      "id_str": "2485229282",
#      "screen_name": "josephsirosh",
#      "name": "Joseph Sirosh"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       116,
#       132
#      ],
#      "text": "MachineLearning"
#     },
#     {
#      "indices": [
#       133,
#       140
#      ],
#      "text": "azureml"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/c8A3tlu9Kn",
#      "indices": [
#       92,
#       114
#      ],
#      "expanded_url": "http://aka.ms/mrbmzn",
#      "display_url": "aka.ms/mrbmzn"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 9,
#   "id_str": "520039938277244928",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Predict the 2014 U.S. Elections and more - at Microsoft Prediction Lab -- http://t.co/c8A3tlu9Kn  #MachineLearning #azureml",
#    "in_reply_to_status_id": null,
#    "id": 520021451915550720,
#    "favorite_count": 3,
#    "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [],
#     "hashtags": [
#      {
#       "indices": [
#        98,
#        114
#       ],
#       "text": "MachineLearning"
#      },
#      {
#       "indices": [
#        115,
#        123
#       ],
#       "text": "azureml"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/c8A3tlu9Kn",
#       "indices": [
#        74,
#        96
#       ],
#       "expanded_url": "http://aka.ms/mrbmzn",
#       "display_url": "aka.ms/mrbmzn"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 9,
#    "id_str": "520021451915550720",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 2485229282,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/464737468311289856/UxDeSZ3B_normal.jpeg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 589,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "2485229282",
#     "profile_background_color": "C0DEED",
#     "listed_count": 8,
#     "is_translation_enabled": false,
#     "utc_offset": null,
#     "statuses_count": 64,
#     "description": "Passionate about machine learning, data science and the cloud.",
#     "friends_count": 134,
#     "location": "Bellevue, Washington",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/464737468311289856/UxDeSZ3B_normal.jpeg",
#     "following": false,
#     "geo_enabled": false,
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "josephsirosh",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 4,
#     "name": "Joseph Sirosh",
#     "notifications": false,
#     "url": null,
#     "created_at": "Fri May 09 11:43:57 +0000 2014",
#     "contributors_enabled": false,
#     "time_zone": null,
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Thu Oct 09 01:22:30 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 2784416954,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/513187016226643969/TYiGTEob_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/5w1LTqVZ1v",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://sandradkingportfolio.wordpress.com",
#        "display_url": "sandradkingportfolio.wordpress.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 459,
#    "profile_sidebar_border_color": "000000",
#    "id_str": "2784416954",
#    "profile_background_color": "C0DEED",
#    "listed_count": 2,
#    "is_translation_enabled": false,
#    "utc_offset": -14400,
#    "statuses_count": 2179,
#    "description": "Global Consultant, Ph.D student Education Technology, Walden University. MS in Education Media  Design Technology,  CPA candidate ,Business @sdkbusiness",
#    "friends_count": 2001,
#    "location": "Maryland ",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/513187016226643969/TYiGTEob_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "sandra_king2",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 956,
#    "name": "Sandra D. King ",
#    "notifications": false,
#    "url": "http://t.co/5w1LTqVZ1v",
#    "created_at": "Mon Sep 01 17:13:18 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": "Eastern Time (US & Canada)",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Oct 09 02:35:57 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @josephsirosh: Predict the 2014 U.S. Elections and more - at Microsoft Prediction Lab -- http://t.co/c8A3tlu9Kn  #MachineLearning #azure\u2026",
#   "in_reply_to_status_id": null,
#   "id": 520039761449193472,
#   "favorite_count": 0,
#   "source": "<a href=\"http://www.twitter.com\" rel=\"nofollow\">Twitter for Windows Phone</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 2485229282,
#      "indices": [
#       3,
#       16
#      ],
#      "id_str": "2485229282",
#      "screen_name": "josephsirosh",
#      "name": "Joseph Sirosh"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       116,
#       132
#      ],
#      "text": "MachineLearning"
#     },
#     {
#      "indices": [
#       133,
#       140
#      ],
#      "text": "azureml"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/c8A3tlu9Kn",
#      "indices": [
#       92,
#       114
#      ],
#      "expanded_url": "http://aka.ms/mrbmzn",
#      "display_url": "aka.ms/mrbmzn"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 9,
#   "id_str": "520039761449193472",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Predict the 2014 U.S. Elections and more - at Microsoft Prediction Lab -- http://t.co/c8A3tlu9Kn  #MachineLearning #azureml",
#    "in_reply_to_status_id": null,
#    "id": 520021451915550720,
#    "favorite_count": 3,
#    "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [],
#     "hashtags": [
#      {
#       "indices": [
#        98,
#        114
#       ],
#       "text": "MachineLearning"
#      },
#      {
#       "indices": [
#        115,
#        123
#       ],
#       "text": "azureml"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/c8A3tlu9Kn",
#       "indices": [
#        74,
#        96
#       ],
#       "expanded_url": "http://aka.ms/mrbmzn",
#       "display_url": "aka.ms/mrbmzn"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 9,
#    "id_str": "520021451915550720",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 2485229282,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/464737468311289856/UxDeSZ3B_normal.jpeg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 589,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "2485229282",
#     "profile_background_color": "C0DEED",
#     "listed_count": 8,
#     "is_translation_enabled": false,
#     "utc_offset": null,
#     "statuses_count": 64,
#     "description": "Passionate about machine learning, data science and the cloud.",
#     "friends_count": 134,
#     "location": "Bellevue, Washington",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/464737468311289856/UxDeSZ3B_normal.jpeg",
#     "following": false,
#     "geo_enabled": false,
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "josephsirosh",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 4,
#     "name": "Joseph Sirosh",
#     "notifications": false,
#     "url": null,
#     "created_at": "Fri May 09 11:43:57 +0000 2014",
#     "contributors_enabled": false,
#     "time_zone": null,
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Thu Oct 09 01:22:30 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 41754227,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": true,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/565139568/redshirt_normal.jpg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/rkquDCVhAW",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://weblogs.asp.net/scottgu",
#        "display_url": "weblogs.asp.net/scottgu"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 103673,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "41754227",
#    "profile_background_color": "C0DEED",
#    "listed_count": 5177,
#    "is_translation_enabled": false,
#    "utc_offset": -25200,
#    "statuses_count": 4696,
#    "description": "I live in Seattle and build a few products for Microsoft",
#    "friends_count": 132,
#    "location": "Redmond, WA",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/565139568/redshirt_normal.jpg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "scottgu",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 43,
#    "name": "Scott Guthrie",
#    "notifications": false,
#    "url": "http://t.co/rkquDCVhAW",
#    "created_at": "Fri May 22 04:39:35 +0000 2009",
#    "contributors_enabled": false,
#    "time_zone": "Pacific Time (US & Canada)",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Oct 09 02:35:15 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "Music recommendations @ MLConf 2014 #collaborativefiltering #machinelearning http://t.co/xQtaTIHl7b via @SlideShare",
#   "in_reply_to_status_id": null,
#   "id": 520039382703542274,
#   "favorite_count": 1,
#   "source": "<a href=\"https://dev.twitter.com/docs/tfw\" rel=\"nofollow\">Twitter for Websites</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 9676152,
#      "indices": [
#       104,
#       115
#      ],
#      "id_str": "9676152",
#      "screen_name": "SlideShare",
#      "name": "SlideShare"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       36,
#       59
#      ],
#      "text": "collaborativefiltering"
#     },
#     {
#      "indices": [
#       60,
#       76
#      ],
#      "text": "machinelearning"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/xQtaTIHl7b",
#      "indices": [
#       77,
#       99
#      ],
#      "expanded_url": "http://www.slideshare.net/erikbern/music-recommendations-mlconf-2014",
#      "display_url": "slideshare.net/erikbern/music\u2026"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "520039382703542274",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 45503303,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/2077054950/402855_1781542075306_1742070806_865654_1352097471_n_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 286,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "45503303",
#    "profile_background_color": "C0DEED",
#    "listed_count": 9,
#    "is_translation_enabled": false,
#    "utc_offset": 28800,
#    "statuses_count": 1277,
#    "description": "Associate Research Fellow at Bridgewell\r\nPsychology | Machine Learning | Natural Language Processing | Buddhism",
#    "friends_count": 578,
#    "location": "Taipei, Taiwan",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/2077054950/402855_1781542075306_1742070806_865654_1352097471_n_normal.jpeg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "zerodie",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 29,
#    "name": "ChiaChia Lee",
#    "notifications": false,
#    "url": null,
#    "created_at": "Mon Jun 08 04:54:23 +0000 2009",
#    "contributors_enabled": false,
#    "time_zone": "Taipei",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Oct 09 02:33:45 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @blopeur: \"Intelligence cannot be commoditized\" \nWhy it is dangerous to delay the adoptions of\n#bigdata #machinelearning \nhttp://t.co/0e\u2026",
#   "in_reply_to_status_id": null,
#   "id": 520039199467008000,
#   "favorite_count": 0,
#   "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 25485744,
#      "indices": [
#       3,
#       11
#      ],
#      "id_str": "25485744",
#      "screen_name": "blopeur",
#      "name": "Benoit Hudzia"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       98,
#       106
#      ],
#      "text": "bigdata"
#     },
#     {
#      "indices": [
#       107,
#       123
#      ],
#      "text": "machinelearning"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/0eRTJbtHqa",
#      "indices": [
#       139,
#       140
#      ],
#      "expanded_url": "http://www.linkedin.com/pulse/article/20141006093439-25120861-intelligence-cannot-be-commoditized",
#      "display_url": "linkedin.com/pulse/article/\u2026"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 1,
#   "id_str": "520039199467008000",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "\"Intelligence cannot be commoditized\" \nWhy it is dangerous to delay the adoptions of\n#bigdata #machinelearning \nhttp://t.co/0eRTJbtHqa",
#    "in_reply_to_status_id": null,
#    "id": 520019598771355648,
#    "favorite_count": 0,
#    "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [],
#     "hashtags": [
#      {
#       "indices": [
#        85,
#        93
#       ],
#       "text": "bigdata"
#      },
#      {
#       "indices": [
#        94,
#        110
#       ],
#       "text": "machinelearning"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/0eRTJbtHqa",
#       "indices": [
#        112,
#        134
#       ],
#       "expanded_url": "http://www.linkedin.com/pulse/article/20141006093439-25120861-intelligence-cannot-be-commoditized",
#       "display_url": "linkedin.com/pulse/article/\u2026"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 1,
#    "id_str": "520019598771355648",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 25485744,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/3188051109/46afa03d0f1d4562e1f596f133918be5_normal.jpeg",
#     "profile_sidebar_fill_color": "EFEFEF",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "http://t.co/jPddtQaGE1",
#         "indices": [
#          0,
#          22
#         ],
#         "expanded_url": "http://www.blopeur.org",
#         "display_url": "blopeur.org"
#        }
#       ]
#      },
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 192,
#     "profile_sidebar_border_color": "EEEEEE",
#     "id_str": "25485744",
#     "profile_background_color": "131516",
#     "listed_count": 15,
#     "is_translation_enabled": false,
#     "utc_offset": 3600,
#     "statuses_count": 1119,
#     "description": "Cloud - System Architect, Head of Irish operation @stratoscale ,  Researcher in everything (not evenly) distributed...",
#     "friends_count": 559,
#     "location": "Ireland",
#     "profile_link_color": "009999",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/3188051109/46afa03d0f1d4562e1f596f133918be5_normal.jpeg",
#     "following": false,
#     "geo_enabled": true,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/25485744/1398440130",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#     "screen_name": "blopeur",
#     "lang": "en",
#     "profile_background_tile": true,
#     "favourites_count": 98,
#     "name": "Benoit Hudzia",
#     "notifications": false,
#     "url": "http://t.co/jPddtQaGE1",
#     "created_at": "Fri Mar 20 10:25:28 +0000 2009",
#     "contributors_enabled": false,
#     "time_zone": "Dublin",
#     "protected": false,
#     "default_profile": false,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Thu Oct 09 01:15:08 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 38670441,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme18/bg.gif",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/3641511865/06a74914910ecfbcf220979136ba34f8_normal.jpeg",
#    "profile_sidebar_fill_color": "F6F6F6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/a5J7LFnrgP",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.linkedin.com/profile/view?id=17616353&trk=hb_tab_pro_top",
#        "display_url": "linkedin.com/profile/view?i\u2026"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 5023,
#    "profile_sidebar_border_color": "EEEEEE",
#    "id_str": "38670441",
#    "profile_background_color": "ACDED6",
#    "listed_count": 317,
#    "is_translation_enabled": false,
# ...
#     "favourites_count": 40,
#     "name": "Wilson D'souza",
#     "notifications": false,
#     "url": null,
#     "created_at": "Tue Jan 14 20:27:36 +0000 2014",
#     "contributors_enabled": false,
#     "time_zone": null,
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Wed Oct 08 21:26:54 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 2704548373,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 1137,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "2704548373",
#    "profile_background_color": "C0DEED",
#    "listed_count": 56,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 56736,
#    "description": "NoSQL Digest of tweets.",
#    "friends_count": 11,
#    "location": "",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "NoSQLDigest",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 47,
#    "name": "NoSQL",
#    "notifications": false,
#    "url": null,
#    "created_at": "Sun Aug 03 17:07:24 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Wed Oct 08 21:57:09 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @melisamalala: \"If the machine can learn it, so can we.\" @quantum_tunnel @GA_London #DataScience #machinelearning",
#   "in_reply_to_status_id": null,
#   "id": 519969548981002240,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/#!/download/ipad\" rel=\"nofollow\">Twitter for iPad</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 32554005,
#      "indices": [
#       3,
#       16
#      ],
#      "id_str": "32554005",
#      "screen_name": "melisamalala",
#      "name": "Melisa Malala"
#     },
#     {
#      "id": 22902732,
#      "indices": [
#       60,
#       75
#      ],
#      "id_str": "22902732",
#      "screen_name": "quantum_tunnel",
#      "name": "Dr J Rogel-Salazar"
#     },
#     {
#      "id": 444874885,
#      "indices": [
#       76,
#       86
#      ],
#      "id_str": "444874885",
#      "screen_name": "GA_London",
#      "name": "GA London"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       87,
#       99
#      ],
#      "text": "DataScience"
#     },
#     {
#      "indices": [
#       100,
#       116
#      ],
#      "text": "machinelearning"
#     }
#    ],
#    "urls": []
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 2,
#   "id_str": "519969548981002240",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "\"If the machine can learn it, so can we.\" @quantum_tunnel @GA_London #DataScience #machinelearning",
#    "in_reply_to_status_id": null,
#    "id": 519947600842485761,
#    "favorite_count": 0,
#    "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 22902732,
#       "indices": [
#        42,
#        57
#       ],
#       "id_str": "22902732",
#       "screen_name": "quantum_tunnel",
#       "name": "Dr J Rogel-Salazar"
#      },
#      {
#       "id": 444874885,
#       "indices": [
#        58,
#        68
#       ],
#       "id_str": "444874885",
#       "screen_name": "GA_London",
#       "name": "GA London"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        69,
#        81
#       ],
#       "text": "DataScience"
#      },
#      {
#       "indices": [
#        82,
#        98
#       ],
#       "text": "machinelearning"
#      }
#     ],
#     "urls": []
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 2,
#    "id_str": "519947600842485761",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 32554005,
#     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/845085430/fe32798d812dbac81fa6c127c1d4c366.jpeg",
#     "verified": false,
#     "profile_text_color": "362720",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/490248816210497536/9TuaKhW7_normal.jpeg",
#     "profile_sidebar_fill_color": "E5507E",
#     "entities": {
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 846,
#     "profile_sidebar_border_color": "FFFFFF",
#     "id_str": "32554005",
#     "profile_background_color": "104663",
#     "listed_count": 6,
#     "is_translation_enabled": false,
#     "utc_offset": 10800,
#     "statuses_count": 8944,
#     "description": "LSE Postgrad",
#     "friends_count": 126,
#     "location": "",
#     "profile_link_color": "09979C",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/490248816210497536/9TuaKhW7_normal.jpeg",
#     "following": false,
#     "geo_enabled": true,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/32554005/1353191470",
#     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/845085430/fe32798d812dbac81fa6c127c1d4c366.jpeg",
#     "screen_name": "melisamalala",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 1463,
#     "name": "Melisa Malala",
#     "notifications": false,
#     "url": null,
#     "created_at": "Fri Apr 17 20:16:11 +0000 2009",
#     "contributors_enabled": false,
#     "time_zone": "Nairobi",
#     "protected": false,
#     "default_profile": false,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "lang": "en",
#    "created_at": "Wed Oct 08 20:29:02 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 1846825063,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000520913369/fe22b02ae069d9b82bcc99b97cb1315b_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 74,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "1846825063",
#    "profile_background_color": "C0DEED",
#    "listed_count": 7,
#    "is_translation_enabled": false,
#    "utc_offset": 3600,
#    "statuses_count": 401,
#    "description": "Data Science info and links. Maintained by Dr J Rogel-Salazar @quantum_tunnel",
#    "friends_count": 197,
#    "location": "UK",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/378800000520913369/fe22b02ae069d9b82bcc99b97cb1315b_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "hidden_node",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 0,
#    "name": "Data Science",
#    "notifications": false,
#    "url": null,
#    "created_at": "Mon Sep 09 14:37:10 +0000 2013",
#    "contributors_enabled": false,
#    "time_zone": "London",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "lang": "en",
#   "created_at": "Wed Oct 08 21:56:15 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @melisamalala: \"If the machine can learn it, so can we.\" @quantum_tunnel @GA_London #DataScience #machinelearning",
#   "in_reply_to_status_id": null,
#   "id": 519969012596617216,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/#!/download/ipad\" rel=\"nofollow\">Twitter for iPad</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 32554005,
#      "indices": [
#       3,
#       16
#      ],
#      "id_str": "32554005",
#      "screen_name": "melisamalala",
#      "name": "Melisa Malala"
#     },
#     {
#      "id": 22902732,
#      "indices": [
#       60,
#       75
#      ],
#      "id_str": "22902732",
#      "screen_name": "quantum_tunnel",
#      "name": "Dr J Rogel-Salazar"
#     },
#     {
#      "id": 444874885,
#      "indices": [
#       76,
#       86
#      ],
#      "id_str": "444874885",
#      "screen_name": "GA_London",
#      "name": "GA London"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       87,
#       99
#      ],
#      "text": "DataScience"
#     },
#     {
#      "indices": [
#       100,
#       116
#      ],
#      "text": "machinelearning"
#     }
#    ],
#    "urls": []
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 2,
#   "id_str": "519969012596617216",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "\"If the machine can learn it, so can we.\" @quantum_tunnel @GA_London #DataScience #machinelearning",
#    "in_reply_to_status_id": null,
#    "id": 519947600842485761,
#    "favorite_count": 0,
#    "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 22902732,
#       "indices": [
#        42,
#        57
#       ],
#       "id_str": "22902732",
#       "screen_name": "quantum_tunnel",
#       "name": "Dr J Rogel-Salazar"
#      },
#      {
#       "id": 444874885,
#       "indices": [
#        58,
#        68
#       ],
#       "id_str": "444874885",
#       "screen_name": "GA_London",
#       "name": "GA London"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        69,
#        81
#       ],
#       "text": "DataScience"
#      },
#      {
#       "indices": [
#        82,
#        98
#       ],
#       "text": "machinelearning"
#      }
#     ],
#     "urls": []
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 2,
#    "id_str": "519947600842485761",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 32554005,
#     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/845085430/fe32798d812dbac81fa6c127c1d4c366.jpeg",
#     "verified": false,
#     "profile_text_color": "362720",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/490248816210497536/9TuaKhW7_normal.jpeg",
#     "profile_sidebar_fill_color": "E5507E",
#     "entities": {
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 846,
#     "profile_sidebar_border_color": "FFFFFF",
#     "id_str": "32554005",
#     "profile_background_color": "104663",
#     "listed_count": 6,
#     "is_translation_enabled": false,
#     "utc_offset": 10800,
#     "statuses_count": 8944,
#     "description": "LSE Postgrad",
#     "friends_count": 126,
#     "location": "",
#     "profile_link_color": "09979C",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/490248816210497536/9TuaKhW7_normal.jpeg",
#     "following": false,
#     "geo_enabled": true,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/32554005/1353191470",
#     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/845085430/fe32798d812dbac81fa6c127c1d4c366.jpeg",
#     "screen_name": "melisamalala",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 1463,
#     "name": "Melisa Malala",
#     "notifications": false,
#     "url": null,
#     "created_at": "Fri Apr 17 20:16:11 +0000 2009",
#     "contributors_enabled": false,
#     "time_zone": "Nairobi",
#     "protected": false,
#     "default_profile": false,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "lang": "en",
#    "created_at": "Wed Oct 08 20:29:02 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 22902732,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#    "verified": false,
#    "profile_text_color": "666666",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/425049954609291264/dgTeZwMa_normal.jpeg",
#    "profile_sidebar_fill_color": "252429",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/yPkxTkUYUm",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://quantumtunnel.wordpress.com",
#        "display_url": "quantumtunnel.wordpress.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 1353,
#    "profile_sidebar_border_color": "181A1E",
#    "id_str": "22902732",
#    "profile_background_color": "1A1B1F",
#    "listed_count": 109,
#    "is_translation_enabled": false,
#    "utc_offset": 3600,
#    "statuses_count": 14951,
#    "description": "Physicist... data science, quantum mechanics, ultra-cold matter, nonlinear optics, computational physics... not enough space.",
#    "friends_count": 1121,
#    "location": "Earth... most of the time ",
#    "profile_link_color": "2FC2EF",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/425049954609291264/dgTeZwMa_normal.jpeg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/22902732/1390174780",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#    "screen_name": "quantum_tunnel",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 60,
#    "name": "Dr J Rogel-Salazar",
#    "notifications": false,
#    "url": "http://t.co/yPkxTkUYUm",
#    "created_at": "Thu Mar 05 09:53:27 +0000 2009",
#    "contributors_enabled": false,
#    "time_zone": "London",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "lang": "en",
#   "created_at": "Wed Oct 08 21:54:07 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  }
# ]
